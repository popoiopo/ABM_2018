# %%
import matplotlib.pyplot as plt

x= [-0.014742,-0.017394,-0.047609,-0.007884, 0.315589, -0.506464, -0.467992]
y = [1,2,3,4,5,6,7]
errors = [0.187197, 0.047083, 0.138943, 0.158205, 0.446374, 0.545785, 0.717119]

plt.figure()
plt.errorbar(x,y, xerr=errors, fmt = 'o', color = 'k')
plt.yticks((0,1,2,3,4,5,6,7,8), ('','N', 'beta_c', 'beta_d', 'beta_w', 'Serving Speed', 'Bar1/3_y', 'Bar2/4_y'))
plt.axvline(x=0, color='b', linestyle = '--')
plt.savefig('Boxplot Sensitivity Analysis S1-WaitingTime')
plt.show()

# %%
#Parameter S1 S1_conf ST ST_conf
N = [-0.014742, 0.187197, 0.039731, 0.078568]
beta_c = [-0.017394, 0.047083, 0.002540, 0.005042]
beta_d =[-0.047609, 0.138943, 0.063836, 0.191433]
beta_w =[-0.007884, 0.158205, 0.036211, 0.082458]
serving_speed =[0.315589, 0.446374, 0.310229, 0.511491]
bar1_y =[-0.506464, 0.545785, 0.336205, 0.269683]
bar2_y =[-0.467992, 0.717119, 0.478481, 0.358605]

# %%
x= [N[2],beta_c[2],beta_d[2],beta_w[2], serving_speed[2], bar1_y[2], bar2_y[2]]
y = [1,2,3,4,5,6,7]
errors = [N[3],beta_c[3],beta_d[3],beta_w[3], serving_speed[3], bar1_y[3], bar2_y[3]]
plt.figure()
plt.errorbar(x,y, xerr=errors, fmt = 'o', color = 'k')
plt.yticks((0,1,2,3,4,5,6,7,8), ('','N', 'beta_c', 'beta_d', 'beta_w', 'Serving Speed', 'Bar1/3_y', 'Bar2/4_y'))
plt.axvline(x=0, color='b', linestyle = '--')
plt.savefig('Boxplot Sensitivity Analysis STotal-WaitingTime')
plt.show()

# %%
#Parameter S1 S1_conf ST ST_conf
N =  [0.090731, 0.314016, 0.250653, 0.310065]
beta_c =  [0.152742, 0.193588, 0.167102, 0.211788]
beta_d =  [0.424935, 0.382075, 0.417755, 0.365887]
beta_w =  [0.152742, 0.232284, 0.167102, 0.254123]
serving_speed = [0.090731, 0.393915, 0.417755, 0.410913]
bar1_y  = [0.152742, 0.396362, 0.668407, 0.587854]
bar2_y  = [0.076371, 0.295582, 0.250653, 0.273037]

# %%
x= [N[2],beta_c[2],beta_d[2],beta_w[2], serving_speed[2], bar1_y[2], bar2_y[2]]
y = [1,2,3,4,5,6,7]
errors = [N[3],beta_c[3],beta_d[3],beta_w[3], serving_speed[3], bar1_y[3], bar2_y[3]]
plt.figure()
plt.errorbar(x,y, xerr=errors, fmt = 'o', color = 'k')
plt.yticks((0,1,2,3,4,5,6,7,8), ('','N', 'beta_c', 'beta_d', 'beta_w', 'Serving Speed', 'Bar1/3_y', 'Bar2/4_y'))
plt.axvline(x=0, color='b', linestyle = '--')
plt.savefig('Boxplot Sensitivity Analysis S1-MaxCrowd')
plt.show()

# %%
x= [N[0],beta_c[0],beta_d[0],beta_w[0], serving_speed[0], bar1_y[0], bar2_y[0]]
y = [1,2,3,4,5,6,7]
errors = [N[1],beta_c[1],beta_d[1],beta_w[1], serving_speed[1], bar1_y[1], bar2_y[1]]
plt.figure()
plt.errorbar(x,y, xerr=errors, fmt = 'o', color = 'k')
plt.yticks((0,1,2,3,4,5,6,7,8), ('','N', 'beta_c', 'beta_d', 'beta_w', 'Serving Speed', 'Bar1/3_y', 'Bar2/4_y'))
plt.axvline(x=0, color='b', linestyle = '--')
plt.savefig('Boxplot Sensitivity Analysis STotal-Crowd')
plt.show()
